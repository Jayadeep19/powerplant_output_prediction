# %% [markdown]
# ## explore data

# %%
import pandas as pd
from pathlib import Path
import os


print(os.getcwd())
ROOT_DIR = Path.cwd().parent
csv_path = ROOT_DIR/"data"/"CCPP"/"Folds5x2_pp.xlsx"
# Out:
# /home/jdeep/mlops-zoomcamp/powerplant_output_prediction/src
# Bad pipe message: %s [b'"Not)A;Brand";v="8", "Chromium";v="138", "Google Chrome";']
# Bad pipe message: %s [b'"138"\r\nsec-ch-ua-mobile: ?0\r\nsec-ch-ua-platform: "Windows"\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Wi', b'ows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36\r\nAccept: text/']
# Bad pipe message: %s [b'ml,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/s']
# ...

# %%
df = pd.read_excel(csv_path)
print(df.info())
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB
# None
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %%
print(df.head())
df.plot.density()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90
# <Axes: ylabel='Density'>

# %%
df.mean()
# Out:
# AT      19.651231
# V       54.305804
# AP    1013.259078
# RH      73.308978
# PE     454.365009
# dtype: float64

# %%
features = ['AT', 'V', 'AP', 'RH']
target = ['PE']

# %%
import pickle

with open(ROOT_DIR.joinpath("data", 'processed_data', 'train.pkl'), 'rb') as f_in:
    X_train, y_train = pickle.load(f_in)

# %%
import variables as var

test_df, y = pd.read_pickle(var.TEST_DATA_PATH)
test_df
y
# Out:
# 2513    455.27
# 9411    436.31
# 8745    440.68
# 9085    434.40
# 4950    482.06
#          ...
# 4427    479.78
# 3297    434.52
# 1244    459.38
# 3614    475.24
# 5651    450.64
# Name: PE, Length: 2392, dtype: float64

# %%
df = pd.DataFrame({'A': range(3), 'B': range(1, 4)})
df
# Out:
#    A  B
# 0  0  1
# 1  1  2
# 2  2  3

# %%
type(df["B"])
# Out:
# pandas.core.series.Series
